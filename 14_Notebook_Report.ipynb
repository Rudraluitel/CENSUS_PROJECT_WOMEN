# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Rudra\Desktop\CENSUS_PROJECT_WOMEN\All_Race_Analysis\1_Raw_Data\raw_data1.csv")
df.head()
# Out:
#    White_Female_Pop  White_Births  Hispanic_Female_Pop  Hispanic_Births  \
# 0          45739240       2214288             13642816           969388
# 1          45267948       2209244             13881646           944717
# 2          44790429       2206855             14102302           931798
# 3          44328454       2111818             14328898           884198
# 4          43917126       2111959             14691627           891425
#
#    Asian_Female_Pop  Asian_Births  African_American_Female_Pop  \
# 0           4320327        234796                     10705227
# 1           4385642        243814                     10678168
# 2           4544112        259018                     10704263
# 3           4633277        247937                     10729458
# 4           4821111        249371                     10793190
#
#    African_American_Births  Total_Female_Pop  Total_Births  us  Year
# 0                   634585          76352003       4168720   1  2010
# ...

# %% [markdown]
# # this is  a notebook to perform EDA
# ## the female population
